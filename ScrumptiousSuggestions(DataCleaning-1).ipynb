# %% [markdown]
# <a href="https://colab.research.google.com/github/TulipAggarwal/Scrumptious-Suggestions/blob/main/ScrumptiousSuggestions(DataCleaning).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_excel("/content/IndianFoodDatasetXLS.xlsx")
df = df.dropna()

# %% [markdown]
# #Diet Column Cleaning

# %%
#Changing the values of Diet Column to 7 set unique categories
diet_mapping = {
    'Diabetic Friendly': 'Diabetic Friendly',
    'Vegetarian': 'Vegetarian',
    'High Protein Vegetarian': 'Vegetarian',
    'Non Vegeterian': 'Non Vegetarian',
    'High Protein Non Vegetarian': 'Non Vegetarian',
    'Eggetarian': 'Eggetarian',
    'Vegan': 'Vegan',
    'No Onion No Garlic (Sattvic)': 'Sattvic',
    'Gluten Free': 'Gluten Free',
    'Sugar Free Diet': 'Diabetic Friendly'
}

df['Diet'] = df['Diet'].replace(diet_mapping)
df.head(10)
# Out:
#    Srno                                         RecipeName  \
# 0     1                               Masala Karela Recipe
# 1     2  टमाटर पुलियोगरे रेसिपी - Spicy Tomato Rice (Re...
# 2     3  Ragi Semiya Upma Recipe - Ragi Millet Vermicel...
# 3     4  Gongura Chicken Curry Recipe - Andhra Style Go...
# 4     5  आंध्रा स्टाइल आलम पचड़ी रेसिपी - Adrak Chutney ...
# 5     6  Pudina Khara Pongal Recipe (Rice and Lentils C...
# 6     7         Udupi Style Ash Gourd Coconut Curry Recipe
# 7     8            Mexican Style Black Bean Burrito Recipe
# 8     9                   Spicy Crunchy Masala Idli Recipe
# 9    10  गोभी के पत्तो की चटनी रेसिपी - Cauliflower Lea...
#
#                                 TranslatedRecipeName  \
# 0                               Masala Karela Recipe
# 1                         Spicy Tomato Rice (Recipe)
# 2  Ragi Semiya Upma Recipe - Ragi Millet Vermicel...
# 3  Gongura Chicken Curry Recipe - Andhra Style Go...
# ...

# %%
unique_diet = df['Diet'].unique()
print(unique_diet)
# Out:
# ['Diabetic Friendly' 'Vegetarian' 'Non Vegetarian' 'Eggetarian' 'Vegan'
#  'Sattvic' 'Gluten Free']

# %% [markdown]
# #Cuisine Column Cleaning

# %%
#Changing the values of Cuisine Column to 6 set unique categories

cuisine_mapping = {
    'Indian': 'Indian',
    'South Indian Recipes': 'Indian',
    'Andhra': 'Indian',
    'Udupi': 'Indian',
    'Mexican': 'American',
    'Fusion': 'Fusion',
    'Continental': 'Continental',
    'Bengali Recipes': 'Indian',
    'Punjabi': 'Indian',
    'Chettinad': 'Indian',
    'Tamil Nadu': 'Indian',
    'Maharashtrian Recipes': 'Indian',
    'North Indian Recipes': 'Indian',
    'Italian Recipes': 'Continental',
    'Sindhi': 'Indian',
    'Thai': 'Thai',
    'Chinese': 'Chinese',
    'Kerala Recipes': 'Indian',
    'Gujarati Recipes﻿': 'Indian',
    'Coorg': 'Indian',
    'Rajasthani': 'Indian',
    'Asian': 'Indian',
    'Middle Eastern': 'Indian',
    'Coastal Karnataka': 'Indian',
    'European': 'Continental',
    'Kashmiri': 'Indian',
    'Karnataka': 'Indian',
    'Lucknowi': 'Indian',
    'Hyderabadi': 'Indian',
    'Side Dish': 'Indian',
    'Goan Recipes': 'Indian',
    'Arab': 'Indian',
    'Assamese': 'Indian',
    'Bihari': 'Indian',
    'Malabar': 'Indian',
    'Himachal': 'Indian',
    'Awadhi': 'Indian',
    'Cantonese': 'Chinese',
    'North East India Recipes': 'Indian',
    'Sichuan': 'Chinese',
    'Mughlai': 'Indian',
    'Japanese': 'Chinese',
    'Mangalorean': 'Indian',
    'Vietnamese': 'Chinese',
    'British': 'American',
    'North Karnataka': 'Indian',
    'Parsi Recipes': 'Indian',
    'Greek': 'Continental',
    'Nepalese': 'Indian',
    'Oriya Recipes': 'Indian',
    'French': 'Continental',
    'Indo Chinese': 'Chinese',
    'Konkan': 'Indian',
    'Mediterranean': 'Continental',
    'Sri Lankan': 'Indian',
    'Haryana': 'Indian',
    'Uttar Pradesh': 'Indian',
    'Malvani': 'Indian',
    'Indonesian': 'Indian',
    'African': 'Continental',
    'Shandong': 'Chinese',
    'Korean': 'Chinese',
    'American': 'American',
    'Kongunadu': 'Indian',
    'Pakistani': 'Indian',
    'Caribbean': 'Indian',
    'South Karnataka': 'Indian',
    'Appetizer': 'Indian',
    'Uttarakhand-North Kumaon': 'Indian',
    'World Breakfast': 'American',
    'Malaysian': 'Indian',
    'Dessert': 'Indian',
    'Hunan': 'Chinese',
    'Dinner': 'Indian',
    'Snack': 'Indian',
    'Jewish': 'Indian',
    'Burmese': 'Indian',
    'Afghan': 'Indian',
    'Brunch': 'Indian',
    'Jharkhand': 'Indian',
    'Nagaland': 'Indian',
    'Lunch': 'Indian',
}

df['Cuisine'] = df['Cuisine'].replace(cuisine_mapping)
df.head(10)
# Out:
#    Srno                                         RecipeName  \
# 0     1                               Masala Karela Recipe
# 1     2  टमाटर पुलियोगरे रेसिपी - Spicy Tomato Rice (Re...
# 2     3  Ragi Semiya Upma Recipe - Ragi Millet Vermicel...
# 3     4  Gongura Chicken Curry Recipe - Andhra Style Go...
# 4     5  आंध्रा स्टाइल आलम पचड़ी रेसिपी - Adrak Chutney ...
# 5     6  Pudina Khara Pongal Recipe (Rice and Lentils C...
# 6     7         Udupi Style Ash Gourd Coconut Curry Recipe
# 7     8            Mexican Style Black Bean Burrito Recipe
# 8     9                   Spicy Crunchy Masala Idli Recipe
# 9    10  गोभी के पत्तो की चटनी रेसिपी - Cauliflower Lea...
#
#                                 TranslatedRecipeName  \
# 0                               Masala Karela Recipe
# 1                         Spicy Tomato Rice (Recipe)
# 2  Ragi Semiya Upma Recipe - Ragi Millet Vermicel...
# 3  Gongura Chicken Curry Recipe - Andhra Style Go...
# ...

# %%
unique_diet = df['Cuisine'].unique()
print(unique_diet)
# Out:
# ['Indian' 'American' 'Fusion' 'Continental' 'Thai' 'Chinese']

# %% [markdown]
# #Course Column Cleaning

# %%
#Changing the values of Course Column to 6 set unique categories

course_mapping = {
    'Side Dish': 'Side Dish',
    'Main Course': 'Main Course',
    'South Indian Breakfast': 'Breakfast',
    'Lunch': 'Main Course',
    'Snack': 'Side Dish',
    'Dinner': 'Main Course',
    'Appetizer': 'Appetizer',
    'Indian Breakfast': 'Breakfast',
    'Dessert': 'Dessert',
    'North Indian Breakfast': 'Breakfast',
    'World Breakfast': 'Breakfast',
    'Beverage': 'Beverage',
    'Breakfast': 'Breakfast',
    'Brunch': 'Breakfast',
}

df['Course'] = df['Course'].replace(course_mapping)
df.head(10)
# Out:
#    Srno                                         RecipeName  \
# 0     1                               Masala Karela Recipe
# 1     2  टमाटर पुलियोगरे रेसिपी - Spicy Tomato Rice (Re...
# 2     3  Ragi Semiya Upma Recipe - Ragi Millet Vermicel...
# 3     4  Gongura Chicken Curry Recipe - Andhra Style Go...
# 4     5  आंध्रा स्टाइल आलम पचड़ी रेसिपी - Adrak Chutney ...
# 5     6  Pudina Khara Pongal Recipe (Rice and Lentils C...
# 6     7         Udupi Style Ash Gourd Coconut Curry Recipe
# 7     8            Mexican Style Black Bean Burrito Recipe
# 8     9                   Spicy Crunchy Masala Idli Recipe
# 9    10  गोभी के पत्तो की चटनी रेसिपी - Cauliflower Lea...
#
#                                 TranslatedRecipeName  \
# 0                               Masala Karela Recipe
# 1                         Spicy Tomato Rice (Recipe)
# 2  Ragi Semiya Upma Recipe - Ragi Millet Vermicel...
# 3  Gongura Chicken Curry Recipe - Andhra Style Go...
# ...

# %%
unique_diet = df['Course'].unique()
print(unique_diet)
# Out:
# ['Side Dish' 'Main Course' 'Breakfast' 'Appetizer' 'Dessert' 'Beverage']

# %% [markdown]
# #Making separate dataframes for Hindi and English recipes

# %%
# !pip install langdetect

# %%
from langdetect import detect

def detect_language(text):
    try:
        return detect(str(text))
    except:
        return 'unknown'

# Applying the language detection function to each row
df['DetectedLanguage'] = df['Instructions'].apply(detect_language)

# Creating separate DataFrames for Hindi and English
df_hindi = df[df['DetectedLanguage'] == 'hi']
df_english = df[df['DetectedLanguage'] == 'en']

# Display or save the DataFrames
df_hindi.head(10)

# %%
df_hindi.to_excel('IndianFoodDataset(hindi).xlsx', index=False)
df_english.to_excel('IndianFoodDataset(english).xlsx', index=False)
